# %%
import pandas as pd
import numpy as np
import nltk

import matplotlib.pyplot as plt
import matplotlib as mpl

import seaborn as sns
sns.set()

# %matplotlib inline

# %%
russia_df = pd.read_csv('../csvs/km_tfidf.csv', index_col = 'tweet_id')
del russia_df['Unnamed: 0']
russia_df.sample(2)
# Out:
#                                                            text  cluster_k3  \
# tweet_id
# 7.974736e+17  Anywhere Hillary would take them 😂\r\n#Preside...           1
# 8.395207e+17  Happy #InternationalWomensDay https://t.co/Jwh...           0
#
#               cluster_k4  cluster_k5  cluster_k6  cluster_k7  cluster_k8  \
# tweet_id
# 7.974736e+17           1           0           1           3           1
# 8.395207e+17           1           0           2           3           1
#
#               cluster_k9  cluster_k10  cluster_k11     ...       cluster_k16  \
# tweet_id                                               ...
# 7.974736e+17           0            6            9     ...                11
# 8.395207e+17           0            6            7     ...                 0
#
#               cluster_k17  cluster_k18  cluster_k19  cluster_k25  cluster_k30  \
# tweet_id
# 7.974736e+17           10           14            6            1           12
# ...

# %%
k = 0
cluster_tweets = russia_df[russia_df['cluster_k14'] == k]
print (cluster_tweets.sample(5)['text'].values)
print('Size: {}'.format(len(cluster_tweets)))
# Out:
# ['Wir machen Schluss mit neuen Schulden #Merkelmussbleiben'
#  'Die Wirtschaft von USA zwingt Merkel zu einer Freudschaft, das freut mich aber #TTIP #Merkelmussbleiben'
#  'Deutschland ohne #NATO-Mitgliedschaft existiert nicht! #Merkelmussbleiben Tagebuch'
#  'Nach dem\xa0Anschlag von #Nizza hat #Merkel\xa0ihr Beileid ausgesprochen. Brav gemacht! #Merkelmussbleiben'
#  'Jetzt sehe ich keine Alternative für sie #Merkelmussbleiben']
# Size: 1472
